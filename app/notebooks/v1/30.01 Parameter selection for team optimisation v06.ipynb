# %% [markdown]
# # Set up

# %%
# update path with data dir
import sys
sys.path.append('../../optimiser/')

# %%
import pandas as pd
import patsy
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from mlens.ensemble import SuperLearner
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import PredefinedSplit, RandomizedSearchCV
from sklearn.decomposition import PCA
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import optimiser
import scipy.stats
import itertools
# Out:
# [MLENS] backend: threading

# %% [markdown]
# # Getting data

# %%
file_name = '../csvs/element_gameweek_features_v06.csv'

# %%
element_gameweek_df = pd.read_csv(file_name)

# %%
element_gameweek_df.fillna(
    element_gameweek_df[element_gameweek_df['event'] <= 20].mean(),
    inplace=True
)

# %%
all_element_gameweek_df = element_gameweek_df.copy()

# %%
all_element_gameweek_df['predicted_total_points'] = 0

# %%
[i for i in list(element_gameweek_df.columns) if i not in [
     'safe_web_name',
     'element',
     'event',
     'fixture',
     'team',
     'opposition_team',
     'element_type',
     'minutes',
     'rolling_value_points',
     'total_points',
     
     'expected_total_points_against_opposition_team',
     'rolling_avg_total_points_element_home',
     'rolling_max_total_points_element',
     'rolling_avg_bps_element',
     'expected_total_points_element_home_away',
     'rolling_avg_total_points_element_away',
     'rolling_avg_total_points_own_team',
     'rolling_avg_total_points_against_opposition_team',
     'rolling_avg_minutes_element',
     'rolling_avg_total_points_opposition_team',
     'rolling_avg_dribbles_element',
     'rolling_avg_total_points_against_opposition_team_element_type',
     'rolling_avg_total_points_against_opposition_team_element_type_away',
     'rolling_avg_total_points_against_opposition_team_element_type_home',
     'rolling_avg_goals_conceded_element',
     'rolling_avg_completed_passes_element',
     'rolling_avg_total_points_element_type',
     'rolling_avg_recoveries_element',
]]
# Out:
# ['was_home',
#  'is_sunday',
#  'is_weekday',
#  'is_early',
#  'is_late',
#  'value',
#  'rolling_avg_total_points_element',
#  'has_high_points_ever_element',
#  'rolling_avg_bonus_element',
#  'rolling_avg_goals_scored_element',
#  'rolling_avg_clean_sheets_element',
#  'rolling_avg_assists_element',
#  'rolling_avg_key_passes_element',
#  'rolling_avg_winning_goals_element',
#  'rolling_avg_tackled_element',
#  'rolling_avg_clearances_blocks_interceptions_element',
#  'rolling_avg_big_chances_created_element',
#  'rolling_avg_target_missed_element',
#  'rolling_avg_fouls_element',
#  'rolling_avg_tackles_element',
#  'rolling_avg_open_play_crosses_element',
#  'rolling_avg_offside_element',
#  'rolling_avg_big_chances_missed_element',
#  'rolling_avg_saves_element',
#  'rolling_avg_attempted_passes_element',
#  'rolling_avg_errors_leading_to_goal_element',
#  'rolling_avg_errors_leading_to_goal_attempt_element',
#  'rolling_avg_own_goals_element',
#  'rolling_avg_penalties_concededd_element',
#  'rolling_avg_penalties_missed_element',
#  'rolling_avg_penalties_saved_element',
#  'rolling_avg_red_cards_element',
#  'rolling_avg_yellow_cards_element',
#  'rolling_avg_minutes_element_p3',
#  'rolling_avg_total_points_element_p3',
#  'rolling_avg_goals_scored_opposition_team',
#  'rolling_avg_goals_conceded_opposition_team',
#  'expected_total_points_against_opposition_team_home_away']

# %% [markdown]
# # Evaluating models

# %% [markdown]
# ## Helpers

# %% [markdown]
# ### Modelling

# %%
formula = \
'total_points ~ C(element_type) + C(team) + C(opposition_team) + ' + \
' + '.join([i for i in element_gameweek_df.columns if i not in
 [
     'safe_web_name',
     'element',
     'event',
     'fixture',
     'team',
     'opposition_team',
     'element_type',
     'minutes',
     'rolling_value_points',
     'total_points',
     
     'expected_total_points_against_opposition_team',
     'rolling_avg_total_points_element_home',
     'rolling_max_total_points_element',
     'rolling_avg_bps_element',
     'expected_total_points_element_home_away',
     'rolling_avg_total_points_element_away',
     'rolling_avg_total_points_own_team',
     'rolling_avg_total_points_against_opposition_team',
     'rolling_avg_minutes_element',
     'rolling_avg_total_points_opposition_team',
     'rolling_avg_dribbles_element',
     'rolling_avg_total_points_against_opposition_team_element_type',
     'rolling_avg_total_points_against_opposition_team_element_type_away',
     'rolling_avg_total_points_against_opposition_team_element_type_home',
     'rolling_avg_goals_conceded_element',
     'rolling_avg_completed_passes_element',
     'rolling_avg_total_points_element_type',
     'rolling_avg_recoveries_element',
 ]])

# %%
scaled_feature_cols = [
    i for i in element_gameweek_df.columns if i not in [
        'safe_web_name', 'element', 'event', 'fixture', 'team',
        'opposition_team', 'element_type', 'was_home', 'is_sunday',
        'is_weekday', 'is_late', 'is_early', 'has_high_points_ever_element',
        'total_points', 'minutes', 'rolling_value_points'
    ]
]

# %%
def calculate_expected_total_points_against_opposition_team_home_away(row):
    a = 'rolling_avg_total_points_against_opposition_team_element_type_home'
    b = 'rolling_avg_total_points_against_opposition_team_element_type_away'
    c = 'rolling_avg_total_points_element'
    d = 'rolling_avg_total_points_element_type'
    if row['was_home'] == 1:
        return row[a] * row[c] / row[d]
    else:
        return row[b] * row[c] / row[d]


def munge_data(df, e, prediction_events, minute_threshold=60):
    # filter weeks after test week
    event_df = df.copy()
    event_df = event_df[event_df['event'] <= e + prediction_events - 1]

    cols = event_df.columns

    # columns that we can fill down
    unknown_element_cols = [
        'was_home',
        'is_sunday',
        'is_weekday',
        'is_early',
        'is_late',
        'value',
        'rolling_avg_total_points_element',
        'has_high_points_ever_element',
        'rolling_avg_bonus_element',
        'rolling_avg_goals_scored_element',
        'rolling_avg_clean_sheets_element',
        'rolling_avg_assists_element',
        'rolling_avg_key_passes_element',
        'rolling_avg_winning_goals_element',
        'rolling_avg_tackled_element',
        'rolling_avg_clearances_blocks_interceptions_element',
        'rolling_avg_big_chances_created_element',
        'rolling_avg_target_missed_element',
        'rolling_avg_fouls_element',
        'rolling_avg_tackles_element',
        'rolling_avg_open_play_crosses_element',
        'rolling_avg_offside_element',
        'rolling_avg_big_chances_missed_element',
        'rolling_avg_saves_element',
        'rolling_avg_attempted_passes_element',
        'rolling_avg_errors_leading_to_goal_element',
        'rolling_avg_errors_leading_to_goal_attempt_element',
        'rolling_avg_own_goals_element',
        'rolling_avg_penalties_concededd_element',
        'rolling_avg_penalties_missed_element',
        'rolling_avg_penalties_saved_element',
        'rolling_avg_red_cards_element',
        'rolling_avg_yellow_cards_element',
        'rolling_avg_minutes_element_p3',
        'rolling_avg_total_points_element_p3',
        'rolling_avg_goals_scored_opposition_team',
        'rolling_avg_goals_conceded_opposition_team',
        'rolling_avg_total_points_element_type',
    ]

    # columns we need to look up
    unknown_opposition_cols = [
        'rolling_avg_goals_scored_opposition_team',
        'rolling_avg_goals_conceded_opposition_team',
        'rolling_avg_total_points_against_opposition_team_element_type_home',
        'rolling_avg_total_points_against_opposition_team_element_type_away',
    ]

    # columns we need to calculate
    unknown_engineered_cols = [
        'expected_total_points_against_opposition_team_home_away',
    ]

    # fill in nans for future data we wouldn't know
    event_df.loc[event_df['event'] > e,
                 unknown_element_cols + unknown_opposition_cols + unknown_engineered_cols
                ] = np.nan
    event_df.sort_values(['element', 'event', 'fixture'], inplace=True)
    # fill down the element data
    event_df[unknown_element_cols] = event_df[unknown_element_cols].fillna(method='ffill')

    # create look up tables for opposition team data
    # we have to look two events back, as some teams won't have played last event
    against_opposition_event_df_1 = event_df[event_df['event'] == e][
        ['opposition_team','element_type','event'] + unknown_opposition_cols].drop_duplicates()


    against_opposition_event_df_2 = event_df[event_df['event'] == e - 1][
        ['opposition_team','element_type','event'] + unknown_opposition_cols].drop_duplicates()

    against_opposition_event_df = pd.concat([against_opposition_event_df_1, against_opposition_event_df_2])

    # get the most recent opposition team data
    against_opposition_event_df = against_opposition_event_df.join(
        against_opposition_event_df.groupby(['opposition_team', 'element_type'])['event'].max(),
        on=['opposition_team', 'element_type'],
        rsuffix='_most_recent')

    against_opposition_event_df = \
    against_opposition_event_df[against_opposition_event_df['event'] == against_opposition_event_df['event_most_recent']]

    event_df = event_df.join(
        against_opposition_event_df.set_index(['opposition_team', 'element_type']),
        on=['opposition_team', 'element_type'],
        rsuffix='_fill')

    # fill in opposition team data from lookup table
    for i in unknown_opposition_cols:
        event_df.loc[event_df['event'] > e, i] = event_df[event_df['event'] > e][i+'_fill']

    event_df['expected_total_points_against_opposition_team_home_away'] = \
    event_df.apply(calculate_expected_total_points_against_opposition_team_home_away, axis=1)

    # filter for frequently appearing players
    event_df = event_df[event_df['rolling_avg_minutes_element_p3'] >= minute_threshold][cols]
    
    return event_df


def split_data(event_df, last_train_event, last_test_event):
    # define train-test split
    test_fold = [-1 if i <= last_train_event else 0 for i in event_df['event'] if i <= last_test_event]
    ps = PredefinedSplit(test_fold)

    # split df into train and test
    for train_index, test_index in ps.split():
        event_df_train, event_df_test = \
        event_df.copy().iloc[train_index], event_df.copy().iloc[test_index]
    
    return event_df_train, event_df_test, ps


def standardise_data(event_df, event_df_train, event_df_test, scaled_feature_cols):
    scale_train = event_df_train.copy()
    scale_test = event_df_test.copy()
    scale_df = event_df.copy()
    scaled_event_df_train = event_df_train.copy()
    scaled_event_df_test = event_df_test.copy()
    scaled_event_df = event_df.copy()

    scaler = StandardScaler().fit(scale_train[scaled_feature_cols].values)

    scale_train = scaler.transform(scale_train[scaled_feature_cols].values)
    scale_test = scaler.transform(scale_test[scaled_feature_cols].values)
    scale_df = scaler.transform(scale_df[scaled_feature_cols].values)

    scaled_event_df_train[scaled_feature_cols] = scale_train
    scaled_event_df_test[scaled_feature_cols] = scale_test
    scaled_event_df[scaled_feature_cols] = scale_df
    
    return scaled_event_df_train, scaled_event_df_test, scaled_event_df


def get_pcs(event_X_train, event_X_test, n_categorical_features):
    pca = PCA()
    pca.fit(event_X_train[:,(n_categorical_features + 1):])
    
    event_X_train_pca = np.concatenate(
        (
            event_X_train[:,:(n_categorical_features + 1)],
            pca.transform(event_X_train[:,(n_categorical_features + 1):])
        ), axis=1)
    
    event_X_test_pca = np.concatenate(
        (
            event_X_test[:,:(n_categorical_features + 1)],
            pca.transform(event_X_test[:,(n_categorical_features + 1):])
        ), axis=1)
    
    return event_X_train_pca, event_X_test_pca


def split_matrices(event_X, event_y, ps):
    for train_index, test_index in ps.split():
        event_X_train, event_X_test = event_X[train_index], event_X[test_index]
        event_y_train, event_y_test = event_y[train_index], event_y[test_index]
    
    return event_X_train, event_X_test, event_y_train, event_y_test


def select_features(event_X, event_X_train, event_X_test, features_index):    
    event_X_train_sel = event_X_train[:,features_index]
    event_X_test_sel = event_X_test[:,features_index]
    event_X_sel = event_X[:,features_index]
    
    return event_X_train_sel, event_X_test_sel, event_X_sel


def retune_model(event_df,
                 last_train_event,
                 last_validation_event,
                 standardise,
                 features_index,
                 model,
                 parameter_space,
                 n_iter_tune=100):
    
    # split data into train and validation set
    event_df_train, event_df_validation, ps_tune = split_data(event_df, last_train_event, last_validation_event)

    # standardise appropriate variables if necessary
    scaled_event_df = event_df.copy()
    if standardise:
        scaled_event_df_train, scaled_event_df_validation, scaled_event_df = \
        standardise_data(event_df, event_df_train, event_df_validation, scaled_feature_cols)        

    # get reponse vector and feature matrix
    event_y, event_X = patsy.dmatrices(formula, scaled_event_df, return_type='matrix')

    # split response vector and feature matrix into train and test
    event_X_train, event_X_validation, event_y_train, event_y_validation = \
    split_matrices(event_X, event_y, ps_tune)

    # if only certain features selected, get their indices
    event_X_train_sel = event_X_train
    event_X_validation_sel = event_X_validation
    event_X_sel = event_X
    if features_index:
        event_X_train_sel, event_X_validation_sel, event_X_sel = \
        select_features(event_X, event_X_train, event_X_validation, features_index)
    
    # search hyperparameter space
    tuner = RandomizedSearchCV(
        model,
        parameter_space,
        n_iter=n_iter_tune,
        scoring='neg_mean_squared_error',
        refit=True,
        cv=ps_tune,
        error_score=100, n_jobs=1)
    
    tuner.fit(event_X_sel, event_y.ravel())
    
    return tuner.best_estimator_

# %% [markdown]
# ### Predicting points

# %%
def predict_test_set(df,
                     model,
                     parameter_space=False,
                     prediction_events=1,
                     prediction_weight=1,
                     features_index=False,
                     standardise=False,
                     pcs=False,
                     start=21,
                     end=38,
                     n_iter_tune=100,
                     verbose=0):
    y_pred_arr = []
    y_test_arr = []
    event_df_test_arr = []

    # for each event we want to predict
    for e in range(start, end + 1):
        if verbose > 0:
            print('predicting event', e)
        
        # munge data
        event_df = munge_data(df, e, prediction_events, minute_threshold=60)

        # split df into train and test
        event_df_train, event_df_test, ps = split_data(event_df, e - 1, 38)
        
        # standardise appropriate variables if necessary
        scaled_event_df = event_df.copy()
        if standardise:
            scaled_event_df_train, scaled_event_df_test, scaled_event_df = \
            standardise_data(event_df, event_df_train, event_df_test, scaled_feature_cols)        

        # get reponse vector and feature matrix
        event_y, event_X = patsy.dmatrices(formula, scaled_event_df, return_type='matrix')
        
        # split response vector and feature matrix into train and test
        event_X_train, event_X_test, event_y_train, event_y_test = \
        split_matrices(event_X, event_y, ps)
        
        # get pcs if necessary
        if pcs:
            n_categorical_features = event_X.design_info.column_names.index('value') - 1
            event_X_train, event_X_test = get_pcs(event_X_train, event_X_test, n_categorical_features)
        
        # if only certain features selected, get their indices
        event_X_train_sel = event_X_train
        event_X_test_sel = event_X_test
        event_X_sel = event_X
        if features_index:
            event_X_train_sel, event_X_test_sel, event_X_sel = \
            select_features(event_X, event_X_train, event_X_test, features_index)
            
        # retune hyperparameters
        if parameter_space:
            model = retune_model(event_df,
                                 e - 6,
                                 e - 1,
                                 standardise,
                                 features_index,
                                 model,
                                 parameter_space,
                                 n_iter_tune)

        # fit model on training data
        model.fit(event_X_train_sel, event_y_train.ravel())
        # predict test event
        event_y_pred = model.predict(event_X_test_sel).flatten()
        
        # collect predictions and observations 
        y_pred_arr.append(event_y_pred)
        y_test_arr.append(event_y_test)
        
        event_df_test['predicted_total_points'] = event_y_pred
        event_df_test['prediction_event'] = e
        
        event_df_test_arr.append(event_df_test)
        
    
    return np.concatenate(y_pred_arr).ravel(), np.concatenate(y_test_arr).ravel(), pd.concat(event_df_test_arr)

# %% [markdown]
# ### Constructing teams

# %%
def get_event_players(
    df,
    e,
    prediction_events,
    optimise_key,
    prediction_weight):
    
    event_players = df.copy()
    
    event_players = \
    event_players[
        (event_players['prediction_event'] == e)
        & (event_players['event'] <= e + prediction_events - 1)
    ]        
    present_elements = event_players['element'].drop_duplicates().values
    all_df = all_element_gameweek_df.copy()
    all_df = all_df[all_df['event'] == e]
    all_df['prediction_event'] = e
    event_players = pd.concat([event_players, all_df[~all_df['element'].isin(present_elements)]])
    
    
    event_players['event_diff'] = event_players['event'] - event_players['prediction_event']
    event_players['prediction_weight'] = prediction_weight**(event_players['event_diff'])
    event_players['optimise_key_weighted'] = event_players['prediction_weight'] * event_players[optimise_key]
    
    event_players_df = event_players.copy()
    
    event_players_group = event_players.groupby('element')['optimise_key_weighted'].sum()
    event_players = event_players[['element', 'value', 'element_type', 'team']].drop_duplicates()
    event_players = event_players.join(event_players_group, on='element')
    event_players = event_players.to_dict('records')
    
    return event_players, event_players_df

# %%
def construct_event_teams_from_existing(df,
                                        prediction_events=1,
                                        prediction_weight=1,
                                        from_scratch_prediction_events=1,
                                        optimise_key='predicted_total_points',
                                        total_budget=1000,
                                        formation=[1, 5, 4, 1],
                                        start=21,
                                        end=38,
                                        transfer_penalty=4,
                                        transfer_limit=11,
                                        verbose=0):
    first_team_arr = []
    bench_arr = []
    team_total_points_arr = []
    predicted_team_total_points_arr = []
    team_df_arr = []
    transfers_arr = []
    carried_over_transfers = 0
    
    for e in range(start, end + 1):
        if verbose > 0:
            print('predicting event', e)
        
        event_players, event_players_df = get_event_players(
            df,
            e,
            prediction_events,
            optimise_key,
            prediction_weight
        )
        
        from_scratch_event_players, _ = get_event_players(
            df,
            e,
            from_scratch_prediction_events,
            optimise_key,
            prediction_weight
        )
        
        if e == start:
            try:
                event_first_team, event_bench = \
                optimiser.construct_optimal_team_from_scratch(
                    from_scratch_event_players,
                    optimise_key='optimise_key_weighted',
                    total_budget=total_budget,
                    formation=formation,
                )

                first_team_arr.append(event_first_team)
                bench_arr.append(event_bench)
                transfers_arr.append([set(), set()])
                
                event_num_transfers = 1
            except Exception as ex:
                print(e, ex)
                first_team_arr.append([])
                bench_arr.append([])
                transfers_arr.append([])
                
                event_num_transfers = 1
        else:
            try:
                event_first_team, event_bench, event_transfers = \
                optimiser.construct_optimal_team_from_existing(
                    event_players,
                    event_first_team,
                    event_bench,
                    total_budget=total_budget,
                    optimise_key='optimise_key_weighted',
                    transfer_penalty=transfer_penalty,
                    transfer_limit=transfer_limit
                )

                first_team_arr.append(event_first_team)
                bench_arr.append(event_bench)
                transfers_arr.append(event_transfers)
                
                event_num_transfers = len(event_transfers[0])
            except Exception as ex:
                print(e, ex)
                first_team_arr.append(event_first_team)
                bench_arr.append(event_bench)
                transfers_arr.append([set(), set()])
                
                event_num_transfers = 0
        
        event_num_transfers = max(event_num_transfers - carried_over_transfers, 0)
        
        event_team_total_points, event_team_predicted_total_points, event_team_df = \
        optimiser.calculate_team_total_points(event_players_df,
                                              event_first_team,
                                              event_bench,
                                              e,
                                              event_num_transfers,
                                              carried_over_transfers)
        
        if event_num_transfers == 0 and carried_over_transfers == 0:
            carried_over_transfers = 1
        if event_num_transfers in (0, 1) and carried_over_transfers == 1:
            carried_over_transfers = 1
        if event_num_transfers == 1 and carried_over_transfers == 0:
            carried_over_transfers = 0
        if event_num_transfers > 1:
            carried_over_transfers = 0


        team_total_points_arr.append(event_team_total_points)
        predicted_team_total_points_arr.append(event_team_predicted_total_points)
        team_df_arr.append(event_team_df)
    
    return (
        first_team_arr, bench_arr,
        team_total_points_arr,
        predicted_team_total_points_arr,
        team_df_arr,
        transfers_arr
    )

# %% [markdown]
# ## Constructing teams

# %% [markdown]
# ### Ridge regression

# %%
ridge_model = Ridge(alpha=1e-8)

# %%
ridge_features_index = [
    False, False, False, False, False, False, False, False, False, False,
    False, False, False, False, True, False, False, False, False, False, False,
    False, False, False, False, False, False, False, False, False, True, False,
    False, True, False, False, False, False, False, False, False, False, False,
    False, False, False, False, True, False, False, False, False, False, False,
    True, False, False, False, False, False, False, False, False, False, True,
    True, False, False, False, False, False, False, False, False, False, True,
    False, True, False, True
]

# %%
ridge_y_pred, ridge_y_test, ridge_df_test = predict_test_set(
    element_gameweek_df,
    ridge_model,
    standardise=True,
    features_index=ridge_features_index,
    pcs=False,
    prediction_events=5,
    verbose=1,
    start=16,
    end=20
)
# Out:
# predicting event 16
# predicting event 17
# predicting event 18
# predicting event 19
# predicting event 20

# %%
ridge_test_loss = (
    mean_absolute_error(ridge_y_test, ridge_y_pred),
    mean_squared_error(ridge_y_test, ridge_y_pred),
    r2_score(ridge_y_test, ridge_y_pred)
)
ridge_test_loss
# Out:
# (2.164181998048021, 8.817528642087087, 0.11223648493579785)

# %%
prediction_events_arr = [1, 2, 3, 4, 5]
from_scratch_prediction_events_arr = [1, 2, 3, 4, 5]
formation_arr = [
    [1, 5, 4, 1],
    [1, 5, 3, 2],
    [1, 3, 4, 3],
    [1, 4, 3, 3],
    [1, 3, 5, 2],
    [1, 4, 5, 1],
    [1, 4, 4, 2],
    [1, 5, 2, 3],
]
transfer_limit_arr = [1, 2, 3, 4, 11]

parameters_arr = list(itertools.product(
    prediction_events_arr,
    from_scratch_prediction_events_arr,
    formation_arr,
    transfer_limit_arr,
))

len(parameters_arr)
# Out:
# 1000

# %%
results_arr = []

for i in parameters_arr:
    print('iteration ', parameters_arr.index(i))
    prediction_events = i[0]
    from_scratch_prediction_events = i[1]
    formation = i[2]
    transfer_limit = i[3]
    
    d = {
        'prediction_events': prediction_events,
        'from_scratch_prediction_events': from_scratch_prediction_events,
        'formation': formation,
        'transfer_limit': transfer_limit,
    }
    
    print(d)
    
    (
        ridge_first_team_arr,
        ridge_bench_arr,
        ridge_total_points_arr,
        ridge_predicted_total_points_arr,
        ridge_team_df_arr,
        ridge_transfers_arr
    ) = \
    construct_event_teams_from_existing(
        ridge_df_test,
        total_budget=1000,
        prediction_events=prediction_events,
        from_scratch_prediction_events=from_scratch_prediction_events,
        formation=formation,
        transfer_penalty=4,
        transfer_limit=transfer_limit,
        start=16,
        end=20,
        verbose=0
    )


    ridge_total_points = sum(ridge_total_points_arr)
    ridge_mean_transfers = np.mean([len(ridge_transfers_arr[i][0]) for i in range(0, len(ridge_transfers_arr))])
    
    d['total_points'] = ridge_total_points
    d['mean_transfers'] = ridge_mean_transfers
    
    results_arr.append(d)
    
    print(ridge_total_points, ridge_mean_transfers)
# Out:
# iteration  0
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 346 0.2
# iteration  1
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 346 0.2
# iteration  2
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 346 0.2
# iteration  3
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 346 0.2
# iteration  4
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 346 0.2
# iteration  5
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 352 0.2
# iteration  6
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 352 0.2
# iteration  7
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 352 0.2
# iteration  8
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 352 0.2
# iteration  9
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 352 0.2
# iteration  10
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 366 0.2
# iteration  11
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 366 0.2
# iteration  12
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 366 0.2
# iteration  13
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 366 0.2
# iteration  14
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 366 0.2
# iteration  15
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 342 0.6
# iteration  16
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 341 0.8
# iteration  17
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 341 0.8
# iteration  18
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 341 0.8
# iteration  19
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 341 0.8
# iteration  20
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 343 0.4
# iteration  21
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 343 0.4
# iteration  22
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 343 0.4
# iteration  23
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 343 0.4
# iteration  24
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 343 0.4
# iteration  25
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 321 0.4
# iteration  26
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 321 0.4
# iteration  27
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 321 0.4
# iteration  28
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 321 0.4
# iteration  29
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 321 0.4
# iteration  30
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 348 0.2
# iteration  31
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 348 0.2
# iteration  32
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 348 0.2
# iteration  33
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 348 0.2
# iteration  34
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 348 0.2
# iteration  35
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 336 0.2
# iteration  36
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 336 0.2
# iteration  37
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 336 0.2
# iteration  38
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 336 0.2
# iteration  39
# {'prediction_events': 1, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 336 0.2
# iteration  40
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 358 0.4
# iteration  41
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 358 0.4
# iteration  42
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 358 0.4
# iteration  43
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 358 0.4
# iteration  44
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 358 0.4
# iteration  45
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 325 0.6
# iteration  46
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 325 0.6
# iteration  47
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 325 0.6
# iteration  48
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 325 0.6
# iteration  49
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 325 0.6
# iteration  50
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 358 0.4
# iteration  51
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 358 0.4
# iteration  52
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 358 0.4
# iteration  53
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 358 0.4
# iteration  54
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 358 0.4
# iteration  55
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 350 0.2
# iteration  56
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 350 0.2
# iteration  57
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 350 0.2
# iteration  58
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 350 0.2
# iteration  59
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 350 0.2
# iteration  60
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 354 0.4
# iteration  61
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 354 0.4
# iteration  62
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 354 0.4
# iteration  63
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 354 0.4
# iteration  64
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 354 0.4
# iteration  65
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 366 0.6
# iteration  66
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 366 0.6
# iteration  67
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 366 0.6
# iteration  68
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 366 0.6
# iteration  69
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 366 0.6
# iteration  70
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 365 0.8
# iteration  71
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 365 0.8
# iteration  72
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 365 0.8
# iteration  73
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 365 0.8
# iteration  74
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 365 0.8
# iteration  75
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 345 0.2
# iteration  76
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 345 0.2
# iteration  77
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 345 0.2
# iteration  78
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 345 0.2
# iteration  79
# {'prediction_events': 1, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 345 0.2
# iteration  80
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 315 0.4
# iteration  81
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 315 0.4
# iteration  82
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 315 0.4
# iteration  83
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 315 0.4
# iteration  84
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 315 0.4
# iteration  85
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 319 0.6
# iteration  86
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 319 0.6
# iteration  87
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 319 0.6
# iteration  88
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 319 0.6
# iteration  89
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 320 0.6
# iteration  90
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 310 0.4
# iteration  91
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 310 0.4
# iteration  92
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 310 0.4
# iteration  93
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 310 0.4
# iteration  94
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 310 0.4
# iteration  95
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 301 0.4
# iteration  96
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 301 0.4
# iteration  97
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 301 0.4
# iteration  98
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 301 0.4
# iteration  99
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 301 0.4
# iteration  100
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 327 0.4
# iteration  101
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 327 0.4
# iteration  102
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 327 0.4
# iteration  103
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 327 0.4
# iteration  104
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 327 0.4
# iteration  105
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 327 0.2
# iteration  106
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 327 0.2
# iteration  107
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 327 0.2
# iteration  108
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 327 0.2
# iteration  109
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 327 0.2
# iteration  110
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 308 0.2
# iteration  111
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 308 0.2
# iteration  112
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 308 0.2
# iteration  113
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 308 0.2
# iteration  114
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 308 0.2
# iteration  115
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 298 0.4
# iteration  116
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 298 0.4
# iteration  117
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 298 0.4
# iteration  118
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 298 0.4
# iteration  119
# {'prediction_events': 1, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 298 0.4
# iteration  120
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 353 0.6
# iteration  121
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 353 0.6
# iteration  122
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 353 0.6
# iteration  123
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 353 0.6
# iteration  124
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 353 0.6
# iteration  125
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 342 0.6
# iteration  126
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 342 0.6
# iteration  127
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 342 0.6
# iteration  128
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 342 0.6
# iteration  129
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 342 0.6
# iteration  130
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 354 0.4
# iteration  131
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 354 0.4
# iteration  132
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 354 0.4
# iteration  133
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 354 0.4
# iteration  134
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 354 0.4
# iteration  135
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 329 0.4
# iteration  136
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 329 0.4
# iteration  137
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 329 0.4
# iteration  138
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 329 0.4
# iteration  139
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 329 0.4
# iteration  140
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 364 0.6
# iteration  141
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 364 0.6
# iteration  142
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 364 0.6
# iteration  143
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 364 0.6
# iteration  144
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 364 0.6
# iteration  145
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 339 0.2
# iteration  146
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 339 0.2
# iteration  147
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 339 0.2
# iteration  148
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 339 0.2
# iteration  149
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 339 0.2
# iteration  150
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 348 0.6
# iteration  151
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 348 0.6
# iteration  152
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 348 0.6
# iteration  153
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 348 0.6
# iteration  154
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 348 0.6
# iteration  155
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 353 0.2
# iteration  156
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 353 0.2
# iteration  157
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 353 0.2
# iteration  158
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 353 0.2
# iteration  159
# {'prediction_events': 1, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 353 0.2
# iteration  160
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 351 0.4
# iteration  161
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 351 0.4
# iteration  162
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 351 0.4
# iteration  163
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 351 0.4
# iteration  164
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 351 0.4
# iteration  165
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 348 0.6
# iteration  166
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 348 0.6
# iteration  167
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 348 0.6
# iteration  168
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 348 0.6
# iteration  169
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 348 0.6
# iteration  170
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 354 0.4
# iteration  171
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 354 0.4
# iteration  172
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 354 0.4
# iteration  173
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 354 0.4
# iteration  174
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 354 0.4
# iteration  175
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 333 0.6
# iteration  176
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 333 0.6
# iteration  177
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 333 0.6
# iteration  178
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 333 0.6
# iteration  179
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 333 0.6
# iteration  180
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 364 0.6
# iteration  181
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 364 0.6
# iteration  182
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 364 0.6
# iteration  183
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 364 0.6
# iteration  184
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 364 0.6
# iteration  185
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 339 0.2
# iteration  186
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 339 0.2
# iteration  187
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 339 0.2
# iteration  188
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 339 0.2
# iteration  189
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 339 0.2
# iteration  190
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 336 0.4
# iteration  191
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 336 0.4
# iteration  192
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 336 0.4
# iteration  193
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 336 0.4
# iteration  194
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 336 0.4
# iteration  195
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 336 0.2
# iteration  196
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 336 0.2
# iteration  197
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 336 0.2
# iteration  198
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 336 0.2
# iteration  199
# {'prediction_events': 1, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 336 0.2
# iteration  200
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 367 0.6
# iteration  201
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 367 0.6
# iteration  202
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 367 0.6
# iteration  203
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 367 0.6
# iteration  204
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 367 0.6
# iteration  205
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 345 0.6
# iteration  206
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 345 0.6
# iteration  207
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 345 0.6
# iteration  208
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 345 0.6
# iteration  209
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 345 0.6
# iteration  210
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 366 0.2
# iteration  211
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 366 0.2
# iteration  212
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 366 0.2
# iteration  213
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 366 0.2
# iteration  214
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 366 0.2
# iteration  215
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 345 0.6
# iteration  216
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 345 0.6
# iteration  217
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 345 0.6
# iteration  218
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 345 0.6
# iteration  219
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 345 0.6
# iteration  220
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 343 0.6
# iteration  221
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 343 0.6
# iteration  222
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 343 0.6
# iteration  223
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 343 0.6
# iteration  224
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 343 0.6
# iteration  225
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 327 0.6
# iteration  226
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 323 0.6
# iteration  227
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 323 0.6
# iteration  228
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 323 0.6
# iteration  229
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 323 0.6
# iteration  230
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 349 0.6
# iteration  231
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 349 0.6
# iteration  232
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 349 0.6
# iteration  233
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 349 0.6
# iteration  234
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 349 0.6
# iteration  235
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 332 0.4
# iteration  236
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 332 0.4
# iteration  237
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 332 0.4
# iteration  238
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 332 0.4
# iteration  239
# {'prediction_events': 2, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 332 0.4
# iteration  240
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 363 0.6
# iteration  241
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 363 0.6
# iteration  242
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 363 0.6
# iteration  243
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 363 0.6
# iteration  244
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 363 0.6
# iteration  245
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 325 0.6
# iteration  246
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 325 0.6
# iteration  247
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 325 0.6
# iteration  248
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 325 0.6
# iteration  249
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 325 0.6
# iteration  250
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 359 0.6
# iteration  251
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 359 0.6
# iteration  252
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 359 0.6
# iteration  253
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 359 0.6
# iteration  254
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 359 0.6
# iteration  255
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 362 0.6
# iteration  256
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 348 0.8
# iteration  257
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 348 0.8
# iteration  258
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 348 0.8
# iteration  259
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 348 0.8
# iteration  260
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 353 0.6
# iteration  261
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 353 0.6
# iteration  262
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 353 0.6
# iteration  263
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 353 0.6
# iteration  264
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 353 0.6
# iteration  265
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 368 0.8
# iteration  266
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 368 0.8
# iteration  267
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 368 0.8
# iteration  268
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 368 0.8
# iteration  269
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 368 0.8
# iteration  270
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 356 0.8
# iteration  271
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 356 0.8
# iteration  272
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 356 0.8
# iteration  273
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 356 0.8
# iteration  274
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 356 0.8
# iteration  275
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 348 0.4
# iteration  276
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 348 0.4
# iteration  277
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 348 0.4
# iteration  278
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 348 0.4
# iteration  279
# {'prediction_events': 2, 'from_scratch_prediction_events': 2, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 348 0.4
# iteration  280
# {'prediction_events': 2, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 330 0.8
# iteration  281
# {'prediction_events': 2, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 365 0.6
# iteration  331
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 361 0.8
# iteration  332
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 361 0.8
# iteration  333
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 361 0.8
# iteration  334
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 361 0.8
# iteration  335
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 335 0.8
# iteration  336
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 331 1.0
# iteration  337
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 331 1.0
# iteration  338
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 331 1.0
# iteration  339
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 331 1.0
# iteration  340
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 375 0.6
# iteration  341
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 360 0.6
# iteration  342
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 360 0.6
# iteration  343
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 360 0.6
# iteration  344
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 360 0.6
# iteration  345
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 353 0.6
# iteration  346
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 340 0.8
# iteration  347
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 340 0.8
# iteration  348
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 340 0.8
# iteration  349
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 340 0.8
# iteration  350
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 360 0.8
# iteration  351
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 360 0.8
# iteration  352
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 360 0.8
# iteration  353
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 360 0.8
# iteration  354
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 360 0.8
# iteration  355
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 347 0.6
# iteration  356
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 347 0.6
# iteration  357
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 347 0.6
# iteration  358
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 347 0.6
# iteration  359
# {'prediction_events': 2, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 347 0.6
# iteration  360
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 342 0.6
# iteration  361
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 342 0.6
# iteration  362
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 342 0.6
# iteration  363
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 342 0.6
# iteration  364
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 342 0.6
# iteration  365
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 353 0.4
# iteration  366
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 326 1.0
# iteration  367
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 326 1.0
# iteration  368
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 326 1.0
# iteration  369
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 326 1.0
# iteration  370
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 365 0.6
# iteration  371
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 361 0.8
# iteration  372
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 361 0.8
# iteration  373
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 361 0.8
# iteration  374
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 361 0.8
# iteration  375
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 337 0.6
# iteration  376
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 325 0.8
# iteration  377
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 325 0.8
# iteration  378
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 325 0.8
# iteration  379
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 325 0.8
# iteration  380
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 375 0.6
# iteration  381
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 360 0.6
# iteration  382
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 360 0.6
# iteration  383
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 360 0.6
# iteration  384
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 360 0.6
# iteration  385
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 353 0.6
# iteration  386
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 340 0.8
# iteration  387
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 340 0.8
# iteration  388
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 340 0.8
# iteration  389
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 340 0.8
# iteration  390
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 358 0.8
# iteration  391
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 339 1.0
# iteration  392
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 339 1.0
# iteration  393
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 339 1.0
# iteration  394
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 339 1.0
# iteration  395
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 343 0.6
# iteration  396
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 332 1.0
# iteration  397
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 332 1.0
# iteration  398
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 332 1.0
# iteration  399
# {'prediction_events': 2, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 332 1.0
# iteration  400
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 366 0.4
# iteration  401
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 366 0.4
# iteration  402
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 366 0.4
# iteration  403
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 366 0.4
# iteration  404
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 366 0.4
# iteration  405
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 350 0.4
# iteration  406
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 350 0.4
# iteration  407
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 350 0.4
# iteration  408
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 350 0.4
# iteration  409
# {'prediction_events': 3, 'from_scratch_prediction_events': 1, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 350 0.4
# iteration  410
# ...
# 349 0.2
# iteration  880
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 336 0.8
# iteration  881
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 333 1.0
# iteration  882
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 333 1.0
# iteration  883
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 333 1.0
# iteration  884
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 333 1.0
# iteration  885
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 322 0.8
# iteration  886
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 325 1.0
# iteration  887
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 319 0.8
# iteration  888
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 319 0.8
# iteration  889
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 319 0.8
# iteration  890
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 348 0.8
# iteration  891
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 325 0.8
# iteration  892
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 325 0.8
# iteration  893
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 325 0.8
# iteration  894
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 325 0.8
# iteration  895
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 333 0.8
# iteration  896
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 316 1.2
# iteration  897
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 328 1.0
# iteration  898
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 328 1.0
# iteration  899
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 328 1.0
# iteration  900
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 345 0.6
# iteration  901
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 352 1.0
# iteration  902
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 333 0.8
# iteration  903
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 333 0.8
# iteration  904
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 333 0.8
# iteration  905
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 344 0.8
# iteration  906
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 346 1.2
# iteration  907
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 346 1.2
# iteration  908
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 346 1.2
# iteration  909
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 346 1.2
# iteration  910
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 322 0.8
# iteration  911
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 325 1.0
# iteration  912
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 319 0.8
# iteration  913
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 319 0.8
# iteration  914
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 319 0.8
# iteration  915
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 327 0.8
# iteration  916
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 314 1.2
# iteration  917
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 314 1.2
# iteration  918
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 314 1.2
# iteration  919
# {'prediction_events': 5, 'from_scratch_prediction_events': 3, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 314 1.2
# iteration  920
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 365 0.6
# iteration  921
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 368 0.8
# iteration  922
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 368 0.8
# iteration  923
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 368 0.8
# iteration  924
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 368 0.8
# iteration  925
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 347 0.8
# iteration  926
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 361 0.8
# iteration  927
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 361 0.8
# iteration  928
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 361 0.8
# iteration  929
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 361 0.8
# iteration  930
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 365 0.6
# iteration  931
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 354 1.0
# iteration  932
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 354 1.0
# iteration  933
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 354 1.0
# iteration  934
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 354 1.0
# iteration  935
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 332 0.6
# iteration  936
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 337 1.0
# iteration  937
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 334 1.0
# iteration  938
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 334 1.0
# iteration  939
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 334 1.0
# iteration  940
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 375 0.6
# iteration  941
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 380 1.0
# iteration  942
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 380 1.0
# iteration  943
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 380 1.0
# iteration  944
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 380 1.0
# iteration  945
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 358 0.6
# iteration  946
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 352 0.8
# iteration  947
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 352 0.8
# iteration  948
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 352 0.8
# iteration  949
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 352 0.8
# iteration  950
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 352 0.8
# iteration  951
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 352 0.6
# iteration  952
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 352 0.6
# iteration  953
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 352 0.6
# iteration  954
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 352 0.6
# iteration  955
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 356 0.6
# iteration  956
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 356 0.6
# iteration  957
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 356 0.6
# iteration  958
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 356 0.6
# iteration  959
# {'prediction_events': 5, 'from_scratch_prediction_events': 4, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 356 0.6
# iteration  960
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 1}
# 359 0.6
# iteration  961
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 2}
# 362 0.8
# iteration  962
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 3}
# 362 0.8
# iteration  963
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 4}
# 362 0.8
# iteration  964
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 4, 1], 'transfer_limit': 11}
# 362 0.8
# iteration  965
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 1}
# 350 0.6
# iteration  966
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 2}
# 342 1.2
# iteration  967
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 3}
# 342 1.2
# iteration  968
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 4}
# 342 1.2
# iteration  969
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 3, 2], 'transfer_limit': 11}
# 342 1.2
# iteration  970
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 1}
# 365 0.6
# iteration  971
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 2}
# 354 1.0
# iteration  972
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 3}
# 354 1.0
# iteration  973
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 4}
# 354 1.0
# iteration  974
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 4, 3], 'transfer_limit': 11}
# 354 1.0
# iteration  975
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 1}
# 337 0.6
# iteration  976
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 2}
# 345 1.2
# iteration  977
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 3}
# 337 1.0
# iteration  978
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 4}
# 337 1.0
# iteration  979
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 3, 3], 'transfer_limit': 11}
# 337 1.0
# iteration  980
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 1}
# 375 0.6
# iteration  981
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 2}
# 380 1.0
# iteration  982
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 3}
# 380 1.0
# iteration  983
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 4}
# 380 1.0
# iteration  984
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 3, 5, 2], 'transfer_limit': 11}
# 380 1.0
# iteration  985
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 1}
# 358 0.6
# iteration  986
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 2}
# 352 0.8
# iteration  987
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 3}
# 352 0.8
# iteration  988
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 4}
# 352 0.8
# iteration  989
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 5, 1], 'transfer_limit': 11}
# 352 0.8
# iteration  990
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 1}
# 357 0.8
# iteration  991
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 2}
# 337 1.2
# iteration  992
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 3}
# 360 1.4
# iteration  993
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 4}
# 360 1.4
# iteration  994
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 4, 4, 2], 'transfer_limit': 11}
# 360 1.4
# iteration  995
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 1}
# 351 0.6
# iteration  996
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 2}
# 334 1.2
# iteration  997
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 3}
# 330 1.0
# iteration  998
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 4}
# 330 1.0
# iteration  999
# {'prediction_events': 5, 'from_scratch_prediction_events': 5, 'formation': [1, 5, 2, 3], 'transfer_limit': 11}
# 330 1.0

# %%
results_df = pd.DataFrame(results_arr)
results_df['formation'] = results_df['formation'].apply(str)

# %%
results_df[
    results_df['transfer_limit'] == 1
].groupby('formation')['total_points'].describe()
# Out:
#               count    mean        std    min    25%    50%    75%    max
# formation
# [1, 3, 4, 3]   25.0  356.92  14.960838  310.0  354.0  365.0  365.0  369.0
# [1, 3, 5, 2]   25.0  355.96  15.759865  325.0  344.0  353.0  375.0  375.0
# [1, 4, 3, 3]   25.0  338.16  14.786480  301.0  329.0  337.0  346.0  362.0
# [1, 4, 4, 2]   25.0  346.44  13.668943  308.0  343.0  349.0  356.0  365.0
# [1, 4, 5, 1]   25.0  345.28  14.220056  321.0  338.0  353.0  358.0  368.0
# [1, 5, 2, 3]   25.0  339.32  14.194248  298.0  334.0  343.0  349.0  356.0
# [1, 5, 3, 2]   25.0  341.68  13.499136  319.0  329.0  345.0  350.0  368.0
# [1, 5, 4, 1]   25.0  353.32  13.936523  315.0  346.0  356.0  366.0  367.0

# %%
good_formations = [
    '[1, 3, 4, 3]',
    '[1, 3, 5, 2]',
    '[1, 5, 4, 1]'
]

# %%
results_df[
    results_df['formation'].isin(good_formations)
].groupby('transfer_limit')['total_points'].describe()
# Out:
#                 count        mean        std    min    25%    50%    75%  \
# transfer_limit
# 1                75.0  355.400000  14.781288  310.0  345.5  359.0  366.0
# 2                75.0  353.053333  15.611753  310.0  346.0  355.0  365.0
# 3                75.0  352.800000  15.782303  310.0  344.5  355.0  365.0
# 4                75.0  352.800000  15.782303  310.0  344.5  355.0  365.0
# 11               75.0  352.800000  15.782303  310.0  344.5  355.0  365.0
#
#                   max
# transfer_limit
# 1               375.0
# 2               380.0
# 3               380.0
# 4               380.0
# 11              380.0

# %%
results_df[
    (results_df['formation'].isin(good_formations))
    & (results_df['transfer_limit'] == 1)
].groupby('from_scratch_prediction_events')['total_points'].describe()
# Out:
#                                 count        mean        std    min    25%  \
# from_scratch_prediction_events
# 1                                15.0  357.266667  11.234301  343.0  344.0
# 2                                15.0  359.800000   6.247285  351.0  354.0
# 3                                15.0  333.066667  11.125689  310.0  328.5
# 4                                15.0  364.466667   7.836423  353.0  357.5
# 5                                15.0  362.400000  10.245557  342.0  353.5
#
#                                   50%    75%    max
# from_scratch_prediction_events
# 1                               366.0  366.0  367.0
# 2                               359.0  365.0  369.0
# 3                               332.0  340.5  348.0
# 4                               365.0  370.0  375.0
# 5                               365.0  370.0  375.0

# %%
results_df[
    (results_df['formation'].isin(good_formations))
    & (results_df['transfer_limit'] == 1)
].groupby('prediction_events')['total_points'].describe()
# Out:
#                    count        mean        std    min    25%    50%    75%  \
# prediction_events
# 1                   15.0  347.800000  17.280046  310.0  344.5  354.0  358.0
# 2                   15.0  354.600000  16.321765  325.0  342.5  359.0  365.5
# 3                   15.0  357.866667  13.468835  332.0  349.5  365.0  366.5
# 4                   15.0  357.400000  13.436624  331.0  349.0  363.0  366.0
# 5                   15.0  359.333333  11.745313  336.0  349.5  365.0  366.0
#
#                      max
# prediction_events
# 1                  366.0
# 2                  375.0
# 3                  375.0
# 4                  375.0
# 5                  375.0

# %%
results_df[results_df['total_points'] >= 370].sort_values('total_points', ascending=False)
# Out:
#         formation  from_scratch_prediction_events  mean_transfers  \
# 984  [1, 3, 5, 2]                               5             1.0
# 983  [1, 3, 5, 2]                               5             1.0
# 982  [1, 3, 5, 2]                               5             1.0
# 981  [1, 3, 5, 2]                               5             1.0
# 944  [1, 3, 5, 2]                               4             1.0
# 943  [1, 3, 5, 2]                               4             1.0
# 942  [1, 3, 5, 2]                               4             1.0
# 941  [1, 3, 5, 2]                               4             1.0
# 580  [1, 3, 5, 2]                               5             0.6
# 980  [1, 3, 5, 2]                               5             0.6
# 940  [1, 3, 5, 2]                               4             0.6
# 780  [1, 3, 5, 2]                               5             0.6
# 740  [1, 3, 5, 2]                               4             0.6
# 380  [1, 3, 5, 2]                               5             0.6
# 340  [1, 3, 5, 2]                               4             0.6
# 540  [1, 3, 5, 2]                               4             0.6
# 658  [1, 4, 3, 3]                               2             1.0
# 657  [1, 4, 3, 3]                               2             1.0
# 856  [1, 4, 3, 3]                               2             1.0
# 859  [1, 4, 3, 3]                               2             1.0
# 858  [1, 4, 3, 3]                               2             1.0
# 659  [1, 4, 3, 3]                               2             1.0
# 656  [1, 4, 3, 3]                               2             1.0
# 857  [1, 4, 3, 3]                               2             1.0
# 464  [1, 3, 5, 2]                               2             0.8
# 463  [1, 3, 5, 2]                               2             0.8
# 462  [1, 3, 5, 2]                               2             0.8
# 461  [1, 3, 5, 2]                               2             0.8
# 471  [1, 4, 4, 2]                               2             0.8
# 472  [1, 4, 4, 2]                               2             0.8
# 473  [1, 4, 4, 2]                               2             0.8
# 474  [1, 4, 4, 2]                               2             0.8
# 544  [1, 3, 5, 2]                               4             0.8
# 581  [1, 3, 5, 2]                               5             0.8
# 541  [1, 3, 5, 2]                               4             0.8
# 542  [1, 3, 5, 2]                               4             0.8
# 543  [1, 3, 5, 2]                               4             0.8
# 584  [1, 3, 5, 2]                               5             0.8
# 583  [1, 3, 5, 2]                               5             0.8
# 582  [1, 3, 5, 2]                               5             0.8
# 843  [1, 5, 4, 1]                               2             0.8
# 842  [1, 5, 4, 1]                               2             0.8
# 841  [1, 5, 4, 1]                               2             0.8
# 844  [1, 5, 4, 1]                               2             0.8
#
#      prediction_events  total_points  transfer_limit
# 984                  5           380              11
# 983                  5           380               4
# 982                  5           380               3
# 981                  5           380               2
# 944                  5           380              11
# 943                  5           380               4
# 942                  5           380               3
# 941                  5           380               2
# 580                  3           375               1
# 980                  5           375               1
# 940                  5           375               1
# 780                  4           375               1
# 740                  4           375               1
# 380                  2           375               1
# 340                  2           375               1
# 540                  3           375               1
# 658                  4           374               4
# 657                  4           374               3
# 856                  5           374               2
# 859                  5           374              11
# 858                  5           374               4
# 659                  4           374              11
# 656                  4           374               2
# 857                  5           374               3
# 464                  3           373              11
# 463                  3           373               4
# 462                  3           373               3
# 461                  3           373               2
# 471                  3           371               2
# 472                  3           371               3
# 473                  3           371               4
# 474                  3           371              11
# 544                  3           371              11
# 581                  3           371               2
# 541                  3           371               2
# 542                  3           371               3
# 543                  3           371               4
# 584                  3           371              11
# 583                  3           371               4
# 582                  3           371               3
# 843                  5           370               4
# 842                  5           370               3
# 841                  5           370               2
# 844                  5           370              11
