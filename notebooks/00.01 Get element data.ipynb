# %%
from footbot.data import element_data

# %%
element_data.get_element_df()
# Out:
#      element  current_event                    datetime   safe_web_name  \
# 0          1              4  2019-09-08 05:20:38.403236         mustafi
# 1          2              4  2019-09-08 05:20:38.403236        bellerin
# 2          3              4  2019-09-08 05:20:38.403236       kolasinac
# 3          4              4  2019-09-08 05:20:38.403236  maitland-niles
# 4          5              4  2019-09-08 05:20:38.403236        sokratis
# ..       ...            ...                         ...             ...
# 527      419              4  2019-09-08 05:20:38.403236       cavaleiro
# 528      420              4  2019-09-08 05:20:38.403236      dendoncker
# 529      473              4  2019-09-08 05:20:38.403236         vallejo
# 530      487              4  2019-09-08 05:20:38.403236         cutrone
# 531      528              4  2019-09-08 05:20:38.403236            neto
#
#      assists  bonus  bps  chance_of_playing_next_round  \
# ...
